# %% [markdown]
# <a href="https://colab.research.google.com/github/saipuneet07/csa6301-threat-intelligence-and-network-security/blob/main/exp_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
login_logs = [
    ("192.168.1.10", "FAILED"),
    ("192.168.1.20", "SUCCESS"),
    ("192.168.1.10", "FAILED"),
    ("192.168.1.30", "FAILED"),
    ("192.168.1.10", "FAILED"),
    ("192.168.1.30", "FAILED"),
    ("192.168.1.30", "FAILED"),
]

threshold = 3

failed_attempts = {}

print("Analyzing Login Logs...\n")

for ip, status in login_logs:
    if status == "FAILED":
        failed_attempts[ip] = failed_attempts.get(ip, 0) + 1

for ip, count in failed_attempts.items():
    print(f"{ip} -> Failed Attempts: {count}")

    if count >= threshold:
        print(f" ALERT: Possible Intrusion Detected from {ip}!\n")
# Out:
# Analyzing Login Logs...
#
# 192.168.1.10 -> Failed Attempts: 3
#  ALERT: Possible Intrusion Detected from 192.168.1.10!
#
# 192.168.1.30 -> Failed Attempts: 3
#  ALERT: Possible Intrusion Detected from 192.168.1.30!
