# %% [markdown]
# <a href="https://colab.research.google.com/github/saipuneet07/csa6301-threat-intelligence-and-network-security/blob/main/exp_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
log_data = [
    "192.168.1.10 FAILED",
    "192.168.1.20 SUCCESS",
    "192.168.1.10 FAILED",
    "192.168.1.30 FAILED",
    "192.168.1.20 FAILED",
    "192.168.1.10 SUCCESS"
]

failed_count = {}

for entry in log_data:
    ip, status = entry.split()

    if status == "FAILED":
        if ip in failed_count:
            failed_count[ip] += 1
        else:
            failed_count[ip] = 1

print("Failed Login Attempts per IP:\n")

for ip, count in failed_count.items():
    print(ip, ":", count)
# Out:
# Failed Login Attempts per IP:
#
# 192.168.1.10 : 2
# 192.168.1.30 : 1
# 192.168.1.20 : 1
